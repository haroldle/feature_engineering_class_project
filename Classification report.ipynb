# %%
import pandas as pd

# %%
df = pd.read_csv('RF_nri_uniform.csv')

# %%
df.head(100)
# Out:
#                           Unnamed: 0  precision    recall  f1-score    support
# 0      b'1-Acrocarpus fraxinifolius'   0.666667  1.000000  0.800000    4.00000
# 1            b'10-Carapa guianensis'   0.500000  0.428571  0.461538    7.00000
# 2       b'11-Cariniana estrellensis'   0.888889  1.000000  0.941176    8.00000
# 3             b'12-Cedrela fissilis'   1.000000  0.666667  0.800000    6.00000
# 4      b'13-Cedrelinga cateniformis'   0.944444  1.000000  0.971429   17.00000
# 5             b'14-Cordia goeldiana'   1.000000  1.000000  1.000000    5.00000
# 6                b'15-Couratari sp.'   0.800000  0.666667  0.727273    6.00000
# 7                 b'16-Dipteryx sp.'   1.000000  0.666667  0.800000    6.00000
# 8             b'17-Erisma uncinatum'   1.000000  1.000000  1.000000   15.00000
# 9               b'18-Eucalyptus sp.'   1.000000  1.000000  1.000000    2.00000
# 10          b'19-Eugenia pyriformis'   1.000000  1.000000  1.000000   11.00000
# ...

# %%
df = pd.read_csv('RF_uniform.csv')
df.head(100)
# Out:
#                           Unnamed: 0  precision    recall  f1-score  \
# 0      b'1-Acrocarpus fraxinifolius'   0.428571  1.000000  0.600000
# 1            b'10-Carapa guianensis'   0.500000  0.250000  0.333333
# 2       b'11-Cariniana estrellensis'   1.000000  1.000000  1.000000
# 3             b'12-Cedrela fissilis'   0.750000  0.750000  0.750000
# 4      b'13-Cedrelinga cateniformis'   0.769231  0.909091  0.833333
# 5             b'14-Cordia goeldiana'   1.000000  1.000000  1.000000
# 6                b'15-Couratari sp.'   0.727273  0.727273  0.727273
# 7                 b'16-Dipteryx sp.'   1.000000  0.666667  0.800000
# 8             b'17-Erisma uncinatum'   0.555556  0.666667  0.606061
# 9               b'18-Eucalyptus sp.'   1.000000  1.000000  1.000000
# 10          b'19-Eugenia pyriformis'   1.000000  1.000000  1.000000
# 11       b'2-Araucaria angustifolia'   0.923077  1.000000  0.960000
# 12       b'20-Euxylophora paraensis'   0.916667  1.000000  0.956522
# ...

# %%
df = pd.read_csv('SVM_nri_uniform.csv')
df.head(100)
# Out:
#                           Unnamed: 0  precision    recall  f1-score  \
# 0      b'1-Acrocarpus fraxinifolius'   0.285714  0.500000  0.363636
# 1            b'10-Carapa guianensis'   0.545455  0.857143  0.666667
# 2       b'11-Cariniana estrellensis'   0.800000  1.000000  0.888889
# 3             b'12-Cedrela fissilis'   1.000000  1.000000  1.000000
# 4      b'13-Cedrelinga cateniformis'   0.941176  0.941176  0.941176
# 5             b'14-Cordia goeldiana'   1.000000  0.800000  0.888889
# 6                b'15-Couratari sp.'   0.833333  0.833333  0.833333
# 7                 b'16-Dipteryx sp.'   1.000000  0.833333  0.909091
# 8             b'17-Erisma uncinatum'   1.000000  0.866667  0.928571
# 9               b'18-Eucalyptus sp.'   1.000000  1.000000  1.000000
# 10          b'19-Eugenia pyriformis'   1.000000  0.909091  0.952381
# 11       b'2-Araucaria angustifolia'   0.823529  0.933333  0.875000
# 12       b'20-Euxylophora paraensis'   0.882353  0.937500  0.909091
# ...

# %%
df = pd.read_csv('SVM_uniform.csv')
df.head(100)
# Out:
#                           Unnamed: 0  precision    recall  f1-score  \
# 0      b'1-Acrocarpus fraxinifolius'   0.750000  1.000000  0.857143
# 1            b'10-Carapa guianensis'   0.500000  0.750000  0.600000
# 2       b'11-Cariniana estrellensis'   1.000000  1.000000  1.000000
# 3             b'12-Cedrela fissilis'   1.000000  1.000000  1.000000
# 4      b'13-Cedrelinga cateniformis'   1.000000  1.000000  1.000000
# 5             b'14-Cordia goeldiana'   1.000000  1.000000  1.000000
# 6                b'15-Couratari sp.'   0.916667  1.000000  0.956522
# 7                 b'16-Dipteryx sp.'   0.857143  1.000000  0.923077
# 8             b'17-Erisma uncinatum'   0.866667  0.866667  0.866667
# 9               b'18-Eucalyptus sp.'   1.000000  1.000000  1.000000
# 10          b'19-Eugenia pyriformis'   1.000000  1.000000  1.000000
# 11       b'2-Araucaria angustifolia'   1.000000  1.000000  1.000000
# 12       b'20-Euxylophora paraensis'   0.909091  0.909091  0.909091
# ...
